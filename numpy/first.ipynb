# %% [markdown]
# # Numpy Arrays

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Array Creation

# %%
a1 = np.array([1,2,3,4,5,6,7,9])
a2 = np.zeros(10)
a3 = np.ones(10)
a4 = np.random.random(10)
a5 = np.random.randn(10)
a6 = np.linspace(0,1,100)
a7 = np.arange(0,1,0.02)

# %%
a7
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#        0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#        0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58, 0.6 , 0.62, 0.64,
#        0.66, 0.68, 0.7 , 0.72, 0.74, 0.76, 0.78, 0.8 , 0.82, 0.84, 0.86,
#        0.88, 0.9 , 0.92, 0.94, 0.96, 0.98])

# %% [markdown]
# #### Array Operations

# %%
2*a1
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14, 18])

# %%
1/a1
# Out:
# array([1.        , 0.5       , 0.33333333, 0.25      , 0.2       ,
#        0.16666667, 0.14285714, 0.11111111])

# %%
x = np.linspace(0,1,100)
y = x**2

# %%
plt.plot(x,y)

# %%
plt.hist(a4)
# Out:
# (array([2., 0., 1., 2., 0., 0., 2., 0., 2., 1.]),
#  array([0.01142492, 0.10464705, 0.19786918, 0.29109131, 0.38431344,
#         0.47753557, 0.5707577 , 0.66397983, 0.75720196, 0.85042409,
#         0.94364622]),
#  <BarContainer object of 10 artists>)

# %%
def f(x):
    return x**2 * np.sin(x)/np.exp(-x)

x = np.linspace(0,10,100)
y = f(x)
plt.plot(x,y)

# %% [markdown]
# #### Indexing And Slicing

# %%
a1[3:5]
# Out:
# array([4, 5])

# %%
a1[1:]
# Out:
# array([2, 3, 4, 5, 6, 7, 9])

# %%
a1[a1%2 == 0]
# Out:
# array([2, 4, 6])

# %%
a1[a1%2 != 0]
# Out:
# array([1, 3, 5, 7, 9])

# %%
a1[a1 > 4]
# Out:
# array([5, 6, 7, 9])

# %%
a1[a1 >= 5]
# Out:
# array([5, 6, 7, 9])

# %%
name = np.array(['Jim','Luke','Josh','Pete'])
first_name_j = np.vectorize(lambda s: s[0])(name) == 'J'
name[first_name_j]
# Out:
# array(['Jim', 'Josh'], dtype='<U4')

# %% [markdown]
# #### Calculus / Statistics

# %%
n1 = np.random.randn(100)
## A normal distribution is generated with mean zero and median 1
n1
# Out:
# array([-0.69339682, -1.4570699 ,  2.03281107, -0.50325615,  0.41328708,
#         1.19785284,  0.39892374, -0.34401442, -0.51234553, -0.4925963 ,
#         0.18680416,  0.88167378, -1.53934327,  1.36289315,  0.95385377,
#        -0.14203284, -1.69597575,  0.21900179,  0.28050689, -1.57601185,
#        -0.53582558, -0.15839703, -0.27140316, -0.72445606, -1.11950851,
#         1.18243335,  0.1457893 ,  0.00502649, -0.79027449, -0.87337486,
#         0.17207083, -0.66284687,  1.14636837,  0.65912609,  1.63407931,
#        -1.19257594,  0.2291544 , -0.06437619, -0.29366038,  1.00340703,
#        -0.24115748,  0.10049239, -0.43839102,  1.07386977,  0.38063671,
#         0.66132902, -0.66825693, -0.00677393,  0.85345413, -1.21041128,
#         0.09372424, -0.8477873 , -1.37229069,  1.410589  ,  1.28641798,
#         0.1104952 , -2.11349739, -0.03585285,  0.8877788 ,  2.1890609 ,
#        -0.95373416, -0.31434473, -0.07312607, -0.24290393,  0.9827531 ,
#        -0.86386941, -1.1291008 , -0.36994289,  0.40646431,  0.34303936,
#         1.34782266,  0.5421265 ,  0.54631798,  0.90862941,  1.05599884,
#         0.16913849,  1.68969872, -0.77504087, -0.80378787,  0.95320573,
#         1.05217545, -1.45566473,  1.19527574, -0.48991263,  0.36333187,
#         0.2194812 , -0.25559218, -0.12188211,  0.21026036,  0.57190179,
#        -1.12001499, -1.45721145, -0.74108919, -3.25910233, -0.09059616,
#         1.10017935,  0.69545951,  0.16117191, -0.62292673,  0.23890888])

# %%
n2 = 2*n1
## Standard distribution is doubled while mean is zero
n2
# Out:
# array([-1.38679363, -2.9141398 ,  4.06562214, -1.00651229,  0.82657415,
#         2.39570567,  0.79784748, -0.68802883, -1.02469105, -0.98519259,
#         0.37360832,  1.76334757, -3.07868654,  2.72578629,  1.90770753,
#        -0.28406567, -3.3919515 ,  0.43800358,  0.56101377, -3.15202371,
#        -1.07165116, -0.31679406, -0.54280632, -1.44891212, -2.23901702,
#         2.3648667 ,  0.29157861,  0.01005298, -1.58054898, -1.74674972,
#         0.34414165, -1.32569373,  2.29273673,  1.31825218,  3.26815862,
#        -2.38515189,  0.45830879, -0.12875237, -0.58732075,  2.00681406,
#        -0.48231495,  0.20098478, -0.87678203,  2.14773955,  0.76127341,
#         1.32265805, -1.33651386, -0.01354786,  1.70690825, -2.42082255,
#         0.18744848, -1.69557461, -2.74458138,  2.82117799,  2.57283596,
#         0.2209904 , -4.22699479, -0.0717057 ,  1.77555761,  4.3781218 ,
#        -1.90746831, -0.62868945, -0.14625215, -0.48580786,  1.9655062 ,
#        -1.72773882, -2.2582016 , -0.73988578,  0.81292862,  0.68607872,
#         2.69564532,  1.084253  ,  1.09263596,  1.81725882,  2.11199768,
#         0.33827698,  3.37939743, -1.55008173, -1.60757575,  1.90641146,
#         2.10435089, -2.91132947,  2.39055149, -0.97982525,  0.72666374,
#         0.4389624 , -0.51118437, -0.24376422,  0.42052073,  1.14380358,
#        -2.24002997, -2.9144229 , -1.48217838, -6.51820466, -0.18119231,
#         2.20035871,  1.39091902,  0.32234382, -1.24585346,  0.47781776])

# %%
n3 = n2 + 10
## mean is increased by 10
n3
# Out:
# array([ 8.61320637,  7.0858602 , 14.06562214,  8.99348771, 10.82657415,
#        12.39570567, 10.79784748,  9.31197117,  8.97530895,  9.01480741,
#        10.37360832, 11.76334757,  6.92131346, 12.72578629, 11.90770753,
#         9.71593433,  6.6080485 , 10.43800358, 10.56101377,  6.84797629,
#         8.92834884,  9.68320594,  9.45719368,  8.55108788,  7.76098298,
#        12.3648667 , 10.29157861, 10.01005298,  8.41945102,  8.25325028,
#        10.34414165,  8.67430627, 12.29273673, 11.31825218, 13.26815862,
#         7.61484811, 10.45830879,  9.87124763,  9.41267925, 12.00681406,
#         9.51768505, 10.20098478,  9.12321797, 12.14773955, 10.76127341,
#        11.32265805,  8.66348614,  9.98645214, 11.70690825,  7.57917745,
#        10.18744848,  8.30442539,  7.25541862, 12.82117799, 12.57283596,
#        10.2209904 ,  5.77300521,  9.9282943 , 11.77555761, 14.3781218 ,
#         8.09253169,  9.37131055,  9.85374785,  9.51419214, 11.9655062 ,
#         8.27226118,  7.7417984 ,  9.26011422, 10.81292862, 10.68607872,
#        12.69564532, 11.084253  , 11.09263596, 11.81725882, 12.11199768,
#        10.33827698, 13.37939743,  8.44991827,  8.39242425, 11.90641146,
#        12.10435089,  7.08867053, 12.39055149,  9.02017475, 10.72666374,
#        10.4389624 ,  9.48881563,  9.75623578, 10.42052073, 11.14380358,
#         7.75997003,  7.0855771 ,  8.51782162,  3.48179534,  9.81880769,
#        12.20035871, 11.39091902, 10.32234382,  8.75414654, 10.47781776])

# %%
np.percentile(n1,80)
# Out:
# 0.9175446736518684

# %% [markdown]
# #### Integrals and Derivatives

# %%
x = np.linspace(1,10,100)
y = 1/x**2 * np.sin(x)
dydx = np.gradient(y,x)
y_in = np.cumsum(y) * (x[1] - x[0])
plt.plot(x,dydx , c= 'r')
plt.plot(x,y_in, c = 'y')
plt.plot(x,y, c = 'b')
