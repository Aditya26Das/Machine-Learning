# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### 2D line plot

# %% [markdown]
# Used for bivariate analysis
# -->Numerical-Numerical
# -->Numerical-Categorical

# %%
price = []
for i in range(1,11):
    price.append(np.random.randint(1000,10000))

year = []
for i in range(2010,2020):
    year.append(i)

plt.plot(price,year)

# %%
batsman = pd.read_csv('../matplotlib/datasets/sharma-kohli.csv')
batsman
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(batsman['index'],batsman['RG Sharma'])

# %%
plt.plot(batsman['index'],batsman['RG Sharma'],c='b',linestyle='solid',linewidth=3)
plt.plot(batsman['index'],batsman['V Kohli'],c='r',linestyle='dashdot',linewidth=2)
plt.title('Carrier Comparison of Rohit Sharma Vs Virat Kohli')
plt.xlabel('Season of IPL--->')
plt.ylabel('Runs Scored--->')
plt.legend(['Sharma','Kohli'])
plt.grid()

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# Used for bivariate analysis
# -->Numerical-Numerical

# %%
# Find Correlation
df = pd.read_csv('../matplotlib/datasets/batter.csv')
df.head(50)
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.scatter(df['avg'],df['strike_rate'])
plt.title('Avg and Strike Rate analysis of top 50 batsmen')
plt.xlabel('Avg runs scored-->')
plt.ylabel('Strike Rate of Batsman-->')
plt.grid()
