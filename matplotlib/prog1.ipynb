# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### 2D line plot
# Used for by variate analysis
# Numerical-Numerical
# Numerical-Categorical

# %%
price = []
for i in range(1,11):
    price.append(np.random.randint(1000,10000))

year = []
for i in range(2010,2020):
    year.append(i)

plt.plot(price,year)
