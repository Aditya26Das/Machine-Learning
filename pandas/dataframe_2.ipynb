# %%
import pandas as pd 
import numpy as np

# %%
batsman = pd.read_csv('./batsman_runs_ipl.csv')
batsman
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
diabetes = pd.read_csv('./diabetes.csv')
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
ipl = pd.read_csv('./ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies = pd.read_csv('./movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values('imdb_rating',ascending=False)
# Out:
#                          title_x    imdb_id  \
# 41          Family of Thakurganj  tt8897986
# 1628                    Humsafar  tt2403201
# 62                Saand Ki Aankh  tt8108206
# 1435  Final Solution (2003 film)  tt0402178
# 58             Ghost (2019 film)  tt9378950
# ...                          ...        ...
# 70     Keep Safe Distance (film)  tt8876008
# 331           Ek Kahani Julie Ki  tt7997334
# 479         Anuradha (2014 film)  tt3482198
# 407                  I Love Desi  tt4718678
# 236      Babuji Ek Ticket Bambai  tt7881528
#
#                                             poster_path  \
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 62    https://upload.wikimedia.org/wikipedia/en/thum...
# 1435                                                NaN
# 58    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# ...

# %%
movies.sort_values('poster_path',ascending=False).head(5)
# NaN values appear at bottom after sorting
# Out:
#                    title_x    imdb_id  \
# 292     Phobia (2016 film)  tt5743656
# 390                Hey Bro  tt4512230
# 1167  Gangster (2006 film)  tt0495032
# 932             Barah Aana  tt1202517
# 484             Jal (film)  tt2708550
#
#                                             poster_path  \
# 292   https://upload.wikimedia.org/wikipedia/en/thum...
# 390   https://upload.wikimedia.org/wikipedia/en/thum...
# 1167  https://upload.wikimedia.org/wikipedia/en/thum...
# 932   https://upload.wikimedia.org/wikipedia/en/thum...
# 484   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link     title_y  \
# 292    https://en.wikipedia.org/wiki/Phobia_(2016_film)      Phobia
# 390               https://en.wikipedia.org/wiki/Hey_Bro     Hey Bro
# 1167  https://en.wikipedia.org/wiki/Gangster_(2006_f...    Gangster
# 932            https://en.wikipedia.org/wiki/Barah_Aana  Barah Aana
# ...

# %%
movies.sort_values(['imdb_rating','year_of_release','runtime'],ascending=[False,False,True],inplace=True)
movies
# Out:
#                          title_x     imdb_id  \
# 41          Family of Thakurganj   tt8897986
# 1628                    Humsafar   tt2403201
# 62                Saand Ki Aankh   tt8108206
# 58             Ghost (2019 film)   tt9378950
# 1435  Final Solution (2003 film)   tt0402178
# ...                          ...         ...
# 298       Khel Toh Ab Shuru Hoga   tt6656806
# 407                  I Love Desi   tt4718678
# 472           Dee Saturday Night  tt10635372
# 479         Anuradha (2014 film)   tt3482198
# 186         Ek Thi Rani Aisi Bhi   tt6752836
#
#                                             poster_path  \
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 62    https://upload.wikimedia.org/wikipedia/en/thum...
# 58    https://upload.wikimedia.org/wikipedia/en/thum...
# 1435                                                NaN
# ...                                                 ...
# ...
