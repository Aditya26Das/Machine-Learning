# %% [markdown]
# ### Creating Dataframes

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### using lists

# %%
student_marks = [
    [100,100,20],
    [90,80,15],
    [70,90,17]
]

pd.DataFrame(student_marks,columns=['Marks','IQ','Package'])
# Out:
#    Marks   IQ  Package
# 0    100  100       20
# 1     90   80       15
# 2     70   90       17

# %% [markdown]
# #### using dictionary

# %%
student_marks = {
    'Marks': [100,90,70],
    'IQ': [100,80,90],
    'Package': [20,15,17]
}

student_marks = pd.DataFrame(student_marks)
student_marks
# Out:
#    Marks   IQ  Package
# 0    100  100       20
# 1     90   80       15
# 2     70   90       17

# %% [markdown]
# #### using csv

# %%
df = pd.read_csv('./Data for repository.csv')
df
# Out:
#                              Movie Name Release Period Whether Remake  \
# 0                           Golden Boys         Normal             No
# 1                         Kaccha Limboo        Holiday             No
# 2                      Not A Love Story        Holiday             No
# 3                            Qaidi Band        Holiday             No
# 4                             Chaatwali        Holiday             No
# ...                                 ...            ...            ...
# 1693                         Fight Club        Holiday             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
# 1697                   Mr. Hot Mr. Kool         Normal             No
#
#      Whether Franchise     Genre New Actor New Director New Music Director  \
# ...

# %% [markdown]
# ### Attributes

# %%
df.shape
# Out:
# (1698, 14)

# %%
df.dtypes
# Out:
# Movie Name            object
# Release Period        object
# Whether Remake        object
# Whether Franchise     object
# Genre                 object
# New Actor             object
# New Director          object
# New Music Director    object
# Lead Star             object
# Director              object
# Music Director        object
# Number of Screens      int64
# Revenue(INR)           int64
# Budget(INR)            int64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1698, step=1)

# %%
df.columns
# Out:
# Index(['Movie Name', 'Release Period', 'Whether Remake', 'Whether Franchise',
#        'Genre', 'New Actor', 'New Director', 'New Music Director', 'Lead Star',
#        'Director', 'Music Director', 'Number of Screens', 'Revenue(INR)',
#        'Budget(INR)'],
#       dtype='object')

# %%
df.values
# Out:
# array([['Golden Boys', 'Normal', 'No', ..., 5, 5000000, 85000],
#        ['Kaccha Limboo', 'Holiday', 'No', ..., 75, 15000000, 825000],
#        ['Not A Love Story', 'Holiday', 'No', ..., 525, 75000000,
#         56700000],
#        ...,
#        ['Dunno Y Na Jaane Kyun', 'Normal', 'No', ..., 20, 12500000,
#         850000],
#        ['Taj Mahal - An Eternal Love Story', 'Normal', 'No', ..., 135,
#         100000000, 31065000],
#        ['Mr. Hot Mr. Kool', 'Normal', 'No', ..., 30, 27500000, 1300000]],
#       dtype=object)

# %%
df.head()
# Out:
#          Movie Name Release Period Whether Remake Whether Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New Actor New Director New Music Director         Lead Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
df.tail()
# Out:
#                              Movie Name Release Period Whether Remake  \
# 1693                         Fight Club        Holiday             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
# 1697                   Mr. Hot Mr. Kool         Normal             No
#
#      Whether Franchise   Genre New Actor New Director New Music Director  \
# 1693                No  action        No          Yes                 No
# 1694                No   drama        No          Yes                Yes
# 1695                No   drama        No           No                 No
# 1696                No   drama        No          Yes                 No
# 1697                No  comedy        No           No                Yes
#
#         Lead Star               Director  Music Director  Number of Screens  \
# ...

# %%
# Creates a sample space of some size
df.sample(5)
# Out:
#                          Movie Name Release Period Whether Remake  \
# 1410                           Sins         Normal             No
# 1522  M.S. Dhoni - The Untold Story        Holiday             No
# 391                          Frozen        Holiday             No
# 1302               Sauda - The Deal        Holiday             No
# 809                     U R My Jaan         Normal             No
#
#      Whether Franchise       Genre New Actor New Director New Music Director  \
# 1410                No       drama       Yes          Yes                Yes
# 1522                No       drama        No           No                 No
# 391                 No       drama        No          Yes                Yes
# 1302                No       drama        No           No                Yes
# 809                 No  love_story       Yes          Yes                 No
#
#                  Lead Star                 Director     Music Director  \
# ...

# %%
# Gives info about how many missing values in each columns and shows memory space taken in RAM
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          1698 non-null   object
#  1   Release Period      1698 non-null   object
#  2   Whether Remake      1698 non-null   object
#  3   Whether Franchise   1698 non-null   object
#  4   Genre               1698 non-null   object
#  5   New Actor           1698 non-null   object
#  6   New Director        1698 non-null   object
#  7   New Music Director  1698 non-null   object
#  8   Lead Star           1698 non-null   object
#  9   Director            1698 non-null   object
#  10  Music Director      1698 non-null   object
#  11  Number of Screens   1698 non-null   int64
#  12  Revenue(INR)        1698 non-null   int64
#  13  Budget(INR)         1698 non-null   int64
# dtypes: int64(3), object(11)
# memory usage: 185.8+ KB

# %%
df.describe()
# Out:
#        Number of Screens  Revenue(INR)   Budget(INR)
# count        1698.000000  1.698000e+03  1.698000e+03
# mean          553.831567  1.501674e+08  2.377287e+08
# std           782.951839  2.434838e+08  6.134398e+08
# min             1.000000  3.250000e+05  7.250000e+03
# 25%            30.000000  1.500000e+07  1.150000e+06
# 50%           200.000000  5.500000e+07  1.240000e+07
# 75%           800.000000  1.900000e+08  1.778325e+08
# max          4600.000000  2.100000e+09  8.016120e+09

# %%
# isnull tells if there exists a null value -> if true then value is missing and .sum() tells how many missing values are present in a column
df.isnull().sum()
# Out:
# Movie Name            0
# Release Period        0
# Whether Remake        0
# Whether Franchise     0
# Genre                 0
# New Actor             0
# New Director          0
# New Music Director    0
# Lead Star             0
# Director              0
# Music Director        0
# Number of Screens     0
# Revenue(INR)          0
# Budget(INR)           0
# dtype: int64

# %%
# duplicated() gives which row is duplicated -> if true then it is a duplicate and .sum() tells us the number of totl duplicated rows present
df.duplicated().sum()
# Out:
# 2

# %%
# rename, inplace makes the change permanent
student_marks.rename(columns={'Marks': 'percentege','Package':'LPA'},inplace=True)
student_marks
# Out:
#    percentege   IQ  LPA
# 0         100  100   20
# 1          90   80   15
# 2          70   90   17

# %% [markdown]
# ### Mathematical Methods

# %% [markdown]
# ##### Sum

# %%
# Column wise sum
student_marks.sum()
# Out:
# percentege    260
# IQ            270
# LPA            52
# dtype: int64

# %%
student_marks['LPA'].sum()
# Out:
# 52

# %%
# Row wise sum
student_marks.sum(axis=1)
# Out:
# 0    220
# 1    185
# 2    177
# dtype: int64

# %% [markdown]
# Similarly we have mean,median,mode,min,max,standard deviation,variance,etc.

# %% [markdown]
# ### Selecting Rows and Columns

# %% [markdown]
# ##### Fetching Single Column

# %%
df['Revenue(INR)']
# Out:
# 0         5000000
# 1        15000000
# 2        75000000
# 3       210000000
# 4         1000000
#           ...
# 1693     82500000
# 1694      8000000
# 1695     12500000
# 1696    100000000
# 1697     27500000
# Name: Revenue(INR), Length: 1698, dtype: int64

# %% [markdown]
# ##### Fetching Multiple Columns

# %%
df[['Movie Name','Genre','Revenue(INR)']]
# Out:
#                              Movie Name     Genre  Revenue(INR)
# 0                           Golden Boys  suspense       5000000
# 1                         Kaccha Limboo     drama      15000000
# 2                      Not A Love Story  thriller      75000000
# 3                            Qaidi Band     drama     210000000
# 4                             Chaatwali     adult       1000000
# ...                                 ...       ...           ...
# 1693                         Fight Club    action      82500000
# 1694                 Strings Of Paasion     drama       8000000
# 1695              Dunno Y Na Jaane Kyun     drama      12500000
# 1696  Taj Mahal - An Eternal Love Story     drama     100000000
# 1697                   Mr. Hot Mr. Kool    comedy      27500000
#
# [1698 rows x 3 columns]

# %% [markdown]
# ##### Fetching A Single Row

# %%
df.iloc[1]
# Out:
# Movie Name               Kaccha Limboo
# Release Period                 Holiday
# Whether Remake                      No
# Whether Franchise                   No
# Genre                            drama
# New Actor                          Yes
# New Director                        No
# New Music Director                 Yes
# Lead Star             Karan Bhanushali
# Director                 Sagar Ballary
# Music Director         Amardeep Nijjer
# Number of Screens                   75
# Revenue(INR)                  15000000
# Budget(INR)                     825000
# Name: 1, dtype: object

# %% [markdown]
# ##### Fetching MUltiple Rows

# %%
df.iloc[0:8:2]
# Out:
#          Movie Name Release Period Whether Remake Whether Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 2  Not A Love Story        Holiday             No                No  thriller
# 4         Chaatwali        Holiday             No                No     adult
# 6    Dirty Marriage        Holiday             No                No     adult
#
#   New Actor New Director New Music Director     Lead Star         Director  \
# 0       Yes           No                 No  Jeet Goswami       Ravi Varma
# 2        No           No                 No    Mahie Gill  Ram Gopal Verma
# 4       Yes          Yes                Yes    Aadil Khan       Aadil Khan
# 6       Yes           No                Yes        Aakash         Priyanka
#
#    Music Director  Number of Screens  Revenue(INR)  Budget(INR)
# 0   Baba Jagirdar                  5       5000000        85000
# 2  Sandeep Chowta                525      75000000     56700000
# ...

# %%
# Fancy Indexing
df.iloc[[0,8,2]]
# Out:
#          Movie Name Release Period Whether Remake Whether Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 8           Ghajini        Holiday            Yes                No    action
# 2  Not A Love Story        Holiday             No                No  thriller
#
#   New Actor New Director New Music Director     Lead Star         Director  \
# 0       Yes           No                 No  Jeet Goswami       Ravi Varma
# 8        No          Yes                 No    Aamir Khan  A.R. Murugadoss
# 2        No           No                 No    Mahie Gill  Ram Gopal Verma
#
#    Music Director  Number of Screens  Revenue(INR)  Budget(INR)
# 0   Baba Jagirdar                  5       5000000        85000
# 8     A.R. Rehman               1550     520000000   1945820000
# 2  Sandeep Chowta                525      75000000     56700000

# %% [markdown]
# ##### Fetching both rows and columns

# %%
df.iloc[0:3,0:3]
# Out:
#                  Release Period Whether Remake Whether Franchise
# Movie Name
# Golden Boys              Normal             No                No
# Kaccha Limboo           Holiday             No                No
# Not A Love Story        Holiday             No                No
